# %% [markdown]
# # CareNav AI - Colab Demo\n\nCareNav AI is a U.S.-focused healthcare navigation assistant by **Omkar A Dharkar**. It coordinates symptom triage, nearby facility search, and conservative home-care guidance using Google ADK.\n\nSafety note: CareNav AI is educational and does not replace professional medical care. For emergencies in the United States, call 911.

# %% [markdown]
# ## 1. Clone the Repository\n\nReplace the repository URL with your GitHub URL after publishing CareNav AI.

# %%
# !git clone https://github.com/<your-username>/CareNav-AI.git\n# %cd CareNav-AI

# %% [markdown]
# ## 2. Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Configure API Keys\n\nDo not paste real keys into a public notebook. In Colab, prefer Secrets or runtime environment variables.

# %%
import os\n\nos.environ["GOOGLE_API_KEY"] = "your_google_ai_api_key"\nos.environ["GOOGLE_PLACES_API_KEY"] = "your_google_places_api_key"\nos.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "False"\nos.environ["DEFAULT_MODEL"] = "gemini-2.5-flash"

# %% [markdown]
# ## 4. Import the Agent

# %%
from carenav_agents.agent import root_agent\n\nroot_agent.name, root_agent.model

# %% [markdown]
# ## 5. Suggested Test Prompts\n\n- `I have chest pain and feel dizzy. What should I do?`\n- `Find nearby hospitals.`\n- `I have a mild sore throat. Are there safe home-care steps?`
